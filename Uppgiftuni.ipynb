# %%
# Skriv en inledande kommentar som talar om vad programmet gör.
#....
# Placera dina modulimpoter här:
import matplotlib.pyplot as plt
import csv

# Deluppgift 1: Funktioner från deluppgift 1 i ordning.
# Skriv din kod här:
data=[]
with open ("pisadata.csv", "r") as file: #Öppnar filen och sedan läser
    read = csv.reader(file, delimiter = ";")

    for rad in read: #läser filen och använder for sats för att lägga in i en lista
        data.append(rad)
 
def menytxt(): #Meny 
    print("1. Läs in csv-filen")
    print("2. Bästa resp. sämsta resultat år 2018")
    print("3. Matematikkunskaper i norden år 2003 – 2018.")
    print("4. Kontinuerligt förbättrat resp. försämrat år 2003 – 2018.")
    print("5. Kvinnor presterar bättre än män under åren 2003–2018")
    print("6. Avsluta programmet.")
    print("Välj ett menyalternativ (1-6):")
def meny(): # Använder whileloop för att skapa en meny. 
    while True:
        menytxt()
        val = int(input()) #frågar efter num och använder if satser "Meny" för att göra beslut
        if val == 1:
            filename=input("Ange filnamn eller tryck bara Enter för data.csv")
            for i in data[0:5]:          
                print(i)
            break
        elif val ==2:
            pisdatasorted()
            break
        elif val ==3:
            nordTabell()
            nordGraf()
            break
        elif val ==4:
            print(2)
            break
        elif val ==5:
            print(2)
            break       
        elif val ==6:
            break


# Deluppgift 2: Funktioner från deluppgift 2 i ordning.
# Skriv din kod här:
    
def år2018(l,i,TF): # Använder mig av val så det inte behvös repeteras 
    data.sort(reverse = TF, key= lambda i:i [1:]) # Sorterar datan från 2018+ använder sedan reverse för att fixa störst till minst
    for col in data[1:11]: # For sats för att skriva ut data från 1 till 10 
        year18 = col[0:3]
        year18.sort(reverse=True)# sorterar störst till minst mellan female och male mellan 2018
        print(f"{year18[l]}--{year18[i]}") #skriver ut med val om vilken lista som ska ut
    
def pisdatasorted():
    print("De tio länder som hade bäst resultat år 2018")
    print("----------------")
    print("Land   Resultat")
    print("----------------")
    år2018(0,1,True)
    print("----------------")
    print("De tio länder som hade sämst resultat år 2018")
    print("----------------")
    print("Land   Resultat")
    print("----------------")
    år2018(0,2,False)
    print("----------------")
#få medelvärde på alla länder
        


#print(allaländer)
# Deluppgift 3: Funktioner från deluppgift 3 i ordning.
# Skriv din kod här:
def nordTabell():  
    data.sort(reverse = False, key= lambda k:k[0]) #sort list
    land = ["Sweden","Norway","Denmark","Finland","Iceland"] #skapar en lista för att söka på länder
    år = [2018,2015,2012,2009,2006,2003]
    länder = [] #en lista 

    for w in land: # skapar for loops för att söka på de länder vi letar efter
        for rad in data:
            if rad[0] == w: #söker på rad 0 och sedan lägger till den i listan om det matchar listan
                länder.append(rad)
        for i in länder:
            del i[:-6]#tar bort allt förutom medelvärden från norden 
    länder_sorted =[[row[i] for row in länder] for i in range(len(länder[0]))]
    
    medelländer= [] #skapar lista
    for x in data:#använder mig av for loops för att filtrerar ut
        del x[:-5] 
        medelländer.append(x[0:])   
    del medelländer[0:2]# tar bort land och M/K

    newdata2=[]
    with open ("pisadata.csv", "r") as file: #Gör en ny file read
        read2 = csv.reader(file, delimiter = ";")
        for rad in read2: 
            newdata2.append(rad)        
    for j in newdata2:# använder mig av for loop för att ta bara medel värden mellan 2018 till 2003
        del j[:-6]


    #skapar loops för att välja varje column
    columns = [[row[i] for row in newdata2] for i in range(len(newdata2[0]))]# använder mig av for loops för att välja ut varje column och sedan vända den så det blir enklare att beräkna
    for jj in columns:
        del jj[0:2]
    
    #Skapar medelvärdet
    columns_int = [[int(numb) for numb in j] for j in columns]#ändrar alla medel värden till int så det kan beräknas 
    for i in columns_int: #använder mig av for loop för att få fram hur många värden det finns i hela listan
        newvalue = len(i)   
    columns_sum =[sum(jj) for jj in columns_int]#Använder mig av for loops för sum varje column 
    medelvärdet= [round(jj/newvalue) for jj in columns_sum] # sedan beräkna medelvärdet med hjälp av for loops igen
    medelvärdet.reverse()




    print("\nKunskapsutveckling i matematik enligt PISA-undersökningen 2003 – 2018.")
    print("                               Länder:")
    print("--------------------------------------------------------------------------------------")
    print("År  Sweden Norway Denmark Finland Iceland          Medelvärde alla länder")
    print("--------------------------------------------------------------------------------------")
    
    for år, länder_sorted,medelvärdet in zip(år,länder_sorted,medelvärdet):
        print(f"{år}  {länder_sorted}                 {medelvärdet} ") # den är fel länder ska vara vända...
#----------------------------------------------------------------------------------------------------------------

def nordGraf():

    data.sort(reverse = False, key= lambda k:k[0])### KOlla
    years = [2018,2015,2012,2009,2006,2003]
    land2 = ["Sweden","Norway","Denmark","Finland","Iceland"] #skapar en lista för att söka på länder
    länder2 = [] #en lista 
    newländer = []
    for w in land2: # skapar for loops för att söka på de länder vi letar efter
        for rad in data:
            if rad[0] == w: #söker på rad 0 och sedan lägger till den i listan om det matchar listan
                länder2.append(rad)
        for i in länder2:
            del i[:-6]#tar bort allt förutom medelvärden från norden


    newdata=[]
    with open ("pisadata.csv", "r") as file: #Gör en ny file read
        read = csv.reader(file, delimiter = ";")

        for rad in read: 
            newdata.append(rad)
            
    for j in newdata:# använder mig av for loop för att ta bara medel värden mellan 2018 till 2003
        del j[:-6]

    #skapar loops för att välja varje column
    columns = [[row[i] for row in newdata] for i in range(len(newdata[0]))]# använder mig av for loops för att välja ut varje column och sedan vända den så det blir enklare att beräkna
    for jj in columns:
        del jj[0:2]
    
    #Skapar medelvärdet
    columns_int = [[int(numb) for numb in j] for j in columns]#ändrar alla medel värden till int så det kan beräknas 
    for i in columns_int: #använder mig av for loop för att få fram hur många värden det finns i hela listan
        newvalue = len(i)   
    columns_sum =[sum(jj) for jj in columns_int]#Använder mig av for loops för sum varje column 
    medelvärdet= [round(jj/newvalue) for jj in columns_sum] # sedan beräkna medelvärdet med hjälp av for loops igen
    medelvärdet.reverse()


    länder_int = [[int(num) for num in k] for k in länder2] #gör länder till int för att sedan kunna lägga i plot
    vänd_länder = [jj.reverse() for jj in länder_int] #vänder allt så att alla länder börjar från 2003.. 
    print(len(länder2))
    sweden = länder_int[0]
    norway = länder_int[1]
    denmark = länder_int[2]
    finland = länder_int[3]
    iceland = länder_int[4]
    years.reverse()
    plt.ylim(450, 550)
    plt.plot(years, sweden,label="Sweden")
    plt.plot(years, norway,label="Norway")
    plt.plot(years, denmark,label="Denmark")
    plt.plot(years, finland,label="Finland")
    plt.plot(years, iceland,label="Iceland")
    plt.plot(years,medelvärdet, label = "Medel")
    plt.xlabel("År")
    plt.ylabel("Poäng")
    plt.title("PISA-undersökningen 2003 – 2018")
    plt.legend()
    plt.grid(True)
    plt.show()

for i in data:
    print(i[18])


# Deluppgift 4: Funktioner från deluppgift 4 i ordning.
# Skriv din kod här:
# Deluppgift 5: Funktioner från deluppgift 5 i ordning.
# Skriv din kod här:
# Huvudprogram med Meny från deluppgift 0. Använd menyrubriker enl.uppgiftsbeskrivningen.
# Skriv din kod här:
# Out:
# 2003
# medel
# 524
# 506
# 529
# 356
# 532
# 516
# 514
# 544
# 511
# 503
# 445
# 550
# 490
# 515
# 360
# 503
# 466
# 534
# 542
# 483
# 493
# 527
# 385
# 538
# 523
# 495
# 490
# 466
# 468
# 498
# 485
# 509
# 527
# 417
# 423
# 508
# 483
# 422

# %%
# Out:
#   File "<ipython-input-6-56f9a240d074>", line 2
#     506
#     ^
# SyntaxError: invalid syntax

# %%
# Skriv en inledande kommentar som talar om vad programmet gör. 


# Placera dina modulimpoter här: 
import matplotlib.pyplot as plt

import csv
# Deluppgift 1: Funktioner från deluppgift 1 i ordning.
# Skriv din kod här:
def read_file(filnamn): #Läser in csv-filen till en flerdimesionell lista, ändrar sedan datatyp på valda objekt från str till int. 
    
    with open(filnamn, 'r',encoding = 'UTF-8' ) as f:
        data_list = []
        csv_reader = csv.reader(f, delimiter = ';')
        for row in csv_reader:
            data_list.append(row)
        for row in data_list[2:]:
            n=1
            for i in row[1:]:
             row[n]= int(i)
             n+=1
     
    return data_list 
def first_five_rows(data):
    temp = []
    for row in data[:5]: 
        temp.append(row)
    print(temp)     
    return None
      
           

# Deluppgift 2: Funktioner från deluppgift 2 i ordning.
# Skriv din kod här:
def best_worst(data, index): #Går igenom CSV-datan och finner de 10 bästa samt sämsta länderna.
    kolum_list =[]
    land = ''
    resultat =0
    for row in data[2:]:        
        land =row[0]
        resultat = row[index]
        rad_list =[land,resultat]
        kolum_list.append(rad_list)
    toplist = sorted(kolum_list,key=lambda x:x[1], reverse=True)   #Sorterar listan efter resultat (fallande)
    top10 = []
    for row in toplist[:10]:
        top10.append(row) 
    bottomlist = sorted(kolum_list,key=lambda x:x[1])  #Sorterar listan efter resultat (Stigande)
    bott10= []
    for row in bottomlist[:10]:
        bott10.append(row)
    
    write_best_worst(top10, bott10) #Anropar utskriftsfunktion.


    return top10, bott10

def write_best_worst(tplist,btlist): # läser in listorna med de tio bästa/sämsta ländernas resultat. Skriver ut 'topplista' och 'sämstalista' i tabeller med tillhörande information.
    max_land = max(len(row[0]) for row in tplist)
    print(f'De tio länder som hade bäst resultat år 2018')
    print('---------------------------------------------')
    print('Land\t\tResultat')
    print('---------------------------------------------')
    for row in tplist:
        print(f'{row[0]}\t\t{str(row[1]).center(max_land)}')

    print('\n')

    print(f'De tio länder som hade sämst resultat år 2018')
    print('---------------------------------------------')
    print('Land\t\tResultat')
    print('---------------------------------------------')
    for row in btlist:
        print(f'{row[0]}\t\t{str(row[1]).center(10)}')       

# Deluppgift 3: Funktioner från deluppgift 3 i ordning.
# Skriv din kod här:


def kolumnmedel(data,index): #läser in csv-data och och index för valt år, räknar ut medelpoängen för vald kollumn i listan för csv-data.
    antal = 0
    sum = 0
    for row in data[2:]:
        
        
        varde = row[index]
        sum += varde
        antal +=1
    medel = sum/antal
    return medel



def arsmedel(data): #läser in csv-data, räknar ut årsmedelpoängen med hjälp av funktionen kolumnmedel. 
    armedel = []
    index =19
    for row in data[2:]:
        index -=1
        if index >=13:
            kolumnmedel(data,index)
            v = kolumnmedel(data,index)
            armedel.append(v)
    return armedel 
        
def country_year(v,w): #läser in csv-data och årsmedelvärdet,skapar listor för de nordiska länderna samt resultaten årsvis.
    Denmark = []
    Finland = []
    Iceland = []
    Norway  = []
    Sweden  = []
    for row in v[2:]:
        for i in row:
            if i == 'Denmark':
                Denmark.append(i)
                for j in range(13,19):
                    Denmark.append(row[j])
            elif i =='Finland':
                Finland.append(i)
                for j in range(13,19):
                    Finland.append(row[j])
            elif i =='Iceland':
                Iceland.append(i)
                for j in range(13,19):
                    Iceland.append(row[j])
            elif i == 'Norway':
                Norway.append(i)
                for j in range(13,19):
                    Norway.append(row[j])
            elif i == 'Sweden':
                Sweden.append(i)
                for j in range(13,19):
                    Sweden.append(row[j])

    list_2018 = ['2018',Sweden[1],Norway[1],Denmark[1],Finland[1],Iceland[1],f'{w[5]:.0f}']
    list_2015 = ['2015',Sweden[2],Norway[2],Denmark[2],Finland[2],Iceland[2],f'{w[4]:.0f}']
    list_2012 = ['2012',Sweden[3],Norway[3],Denmark[3],Finland[3],Iceland[3],f'{w[3]:.0f}']
    list_2009 = ['2009',Sweden[4],Norway[4],Denmark[4],Finland[4],Iceland[4],f'{w[2]:.0f}']
    list_2006 = ['2006',Sweden[5],Norway[5],Denmark[5],Finland[5],Iceland[5],f'{w[1]:.0f}']
    list_2003 = ['2003',Sweden[6],Norway[6],Denmark[6],Finland[6],Iceland[6],f'{w[0]:.0f}']
    return list_2018,list_2015,list_2012,list_2009,list_2006,list_2003, Denmark, Finland, Iceland, Norway, Sweden

def nordtabell(v,w): #läser in csv-data och årsmedelvärdet,skriver ut en tabell utifrån resultatet av de nordiska länderna från varje år.
    
    list_2018,list_2015,list_2012,list_2009,list_2006,list_2003, Denmark, Finland, Iceland, Norway, Sweden =country_year(v,w)
    
   
    print('Kunskapsutveckling i matematik enligt PISA-undersökningen 2003-2018.')
    print('--------------------------------------------------------------------')
    print('                             Länder')
    print('År\tSweden\tNorway\tDenmark\tFinland\tIceland\tMedelvärde\n\t\t\t\t\t\talla länder')
    print('--------------------------------------------------------------------')
    print(f'{list_2018[0]}\t{list_2018[1]}\t{list_2018[2]}\t{list_2018[3]}\t{list_2018[4]}\t{list_2018[5]}\t{list_2018[6]}')
    print(f'{list_2015[0]}\t{list_2015[1]}\t{list_2015[2]}\t{list_2015[3]}\t{list_2015[4]}\t{list_2015[5]}\t{list_2015[6]}')
    print(f'{list_2012[0]}\t{list_2012[1]}\t{list_2012[2]}\t{list_2012[3]}\t{list_2012[4]}\t{list_2012[5]}\t{list_2012[6]}')
    print(f'{list_2009[0]}\t{list_2009[1]}\t{list_2009[2]}\t{list_2009[3]}\t{list_2009[4]}\t{list_2009[5]}\t{list_2009[6]}')
    print(f'{list_2006[0]}\t{list_2006[1]}\t{list_2006[2]}\t{list_2006[3]}\t{list_2006[4]}\t{list_2006[5]}\t{list_2006[6]}')
    print(f'{list_2003[0]}\t{list_2003[1]}\t{list_2003[2]}\t{list_2003[3]}\t{list_2003[4]}\t{list_2003[5]}\t{list_2003[6]}')
    return list_2018,list_2015,list_2012,list_2009,list_2006,list_2003

def nordgraf(v,w): #skapar ett linjediagram för varje lands utveckling från 2003-2018.
    list_2018,list_2015,list_2012,list_2009,list_2006,list_2003, Denmark, Finland, Iceland, Norway, Sweden =country_year(v,w)
    år = [2003,2006,2009,2012,2015,2018]
    X_labels= (['2003', '2006', '2009', '2012', '2015', '2018'])
    plt.plot(år,Sweden [1:7],color = 'y', label = 'Sweden' )
    plt.plot(år,Denmark [1:7], color = 'r', label = 'Denmark' )
    plt.plot(år,Finland [1:7], color = 'b', label = 'Finland' )
    plt.plot(år,Norway [1:7], color = 'purple', label = 'Norway' )
    plt.plot(år,Iceland [1:7], color = 'g', label = 'Iceland' )
    plt.plot(år,w,color = 'black', label = 'Medelvärde' )
    plt.grid(color = 'black')
    plt.gca().set_facecolor('lightblue')
    plt.xlabel('År')
    plt.ylabel('Poäng')
    plt.title('PISA: Kunskapsutvecklingen i matematik 2003-2018')
    plt.xticks(år)

    plt.legend()
    plt.show()
    return None

# Deluppgift 4: Funktioner från deluppgift 4 i ordning.
# Skriv din kod här:

def battresammre(data,utveck): #undersöker utifall ett land i datamängden har en posetiv/negativ trend. Skriver sedan ut länder och resultat i tabeller.
    battre = []
    if utveck ==True:       
        i =0
        if i<6:
            for row in data[2:]:
                comp=1000
                for e in row[13:19]:
                    if e<=comp:
                        i+=1
                        comp= e
                        if i==6:
                            battre.append(row)
                            
                    else: 
                        i=0
                        break
        print('Länder som hela tiden har förbättras sina resultat mellan 2003-2018')
        print('--------------------------------------------------------------------')
        print('                             År och resultat:')
        print('Land\t\t\t2018\t2015\t2012\t2009\t2006\t2003')
        print('--------------------------------------------------------------------')
        print(f'{battre[0][0]}\t\t{battre[0][13]}\t{battre[0][14]}\t{battre[0][15]}\t{battre[0][16]}\t{battre[0][17]}\t{battre[0][18]}\t')                
       
                
                


    elif utveck== False:
        samre = []
        i =0
        if i<6:
            for row in data[2:]:
                comp=0
                for e in row[13:19]:
                    if e>=comp:
                        i+=1
                        comp= e
                        if i==6:
                            samre.append(row)
                            
                    else: 
                        i=0
                        break
        print('Länder som hela tiden har försämrat sina resultat mellan 2003-2018')
        print('--------------------------------------------------------------------')
        print('                             År och resultat:')
        print('Land\t\t\t2018\t2015\t2012\t2009\t2006\t2003')
        print('--------------------------------------------------------------------')
        print(f'{samre[0][0]}\t\t{samre[0][13]}\t{samre[0][14]}\t{samre[0][15]}\t{samre[0][16]}\t{samre[0][17]}\t{samre[0][18]}\t')
        print(f'{samre[1][0]}\t\t\t{samre[1][13]}\t{samre[1][14]}\t{samre[1][15]}\t{samre[1][16]}\t{samre[1][17]}\t{samre[1][18]}\t')                
        print(f'{samre[2][0]}\t\t{samre[2][13]}\t{samre[2][14]}\t{samre[2][15]}\t{samre[2][16]}\t{samre[2][17]}\t{samre[2][18]}\t')
    #print(battre)
    #print(samre)

    
    #print(f'{samre[13]}\t{samre[14]}\t{samre[15]}\t{samre[16]}\t{samre[17]}\t{samre[18]}\t')
    return None





# Deluppgift 5: Funktioner från deluppgift 5 i ordning.
# Skriv din kod här:


# Huvudprogram med Meny från deluppgift 0. Använd menyrubriker enl. uppgiftsbeskrivningen.
# Skriv din kod här:

state = True
while state:
    #Printar ut de olika menyvalen.
     print(f' \n\t1. Läs in CSV-filen. ')
     print(f' \t2. Bästa resp. sämsta resultatet år 2018.')
     print(f' \t3. Matematikkunskaper i norden år 2003 - 2018.')
     print(f' \t4. Kontinuerligt förbättrat resp. försämrat år 2003 – 2018.')
     print(f' \t5. Kvinnor presterar bättre än män under åren 2003–2018.')
     print(f' \t6. Avsluta programmet.')
     print(f'\n Välj ett menyalternativ (1-6) :')
     
     val = input()
     
     if val == '1':#Frågar användaren efter namnet på datafilen. Därefter läses csv-filen in och listan pisadata skapas enligt uppgift 1. Vi förutsätter att csv-filen ligger i arbetskatalogen för VC-code.
         filename =input('Ange filnamn eller tryck bara Enter för pisadata.csv') or 'pisadata.csv'
         pisadata = read_file(filename)
         first_five_rows (pisadata)
     
     elif val == '2':#Skapar tabeller över de tio läder med bästa resp. sämsta resultat 2018 enligt uppgift 2.
         index_2018 = [i for i, value in enumerate(pisadata[0]) if value == '2018'] #söker i datan efter index där 2018 och poängmedelvärdet sammanfaller.  

         # Hitta index för 'medel' i den andra raden i samma kolumn som '2018'
         index_medel = None
         for i, value in enumerate(pisadata[1]):
            if value == 'medel':
                index_medel = i
            break
         
         for idx in index_2018:
           if pisadata[1][idx] == 'medel':
               break
        
         pisadata_sorterad = best_worst(pisadata, idx)
    
     elif val == '3':#Skapar en tabell och ritar ett diagram över matematikkunskaperna i norden enligt uppgift 3.
        arsmedel(pisadata)
        medelvAr = (arsmedel(pisadata))
        print()
        nordtabell(pisadata,medelvAr)
        nordgraf(pisadata,medelvAr)
     elif val == '4':#Skapar tabeller över de länder där resultaten kontinuerligt förbättrats resp. försämrats enligt uppgift 4.
         T = True
         F = False
         battresammre(pisadata,T)
         print()
         battresammre(pisadata,F)
    
     elif val == '5': #Skapar en tabell på när kvinnor presterat bättre än män, enligt uppgift 5.
         print()
     elif val == '6': #Programmet avslutas och en bekräftelse t.ex. ”Programmet är avslutat” skrivs på skärmen.
         print('Programmet är avslutat')
         state = False
     
     else:
         print(f'Felaktig inmatning, försök igen!')
         
     if val !=6:
         nyvarv = input('\nVidare till menyn tryck Enter! ')
# Out:
#
# 	1. Läs in CSV-filen.
#  	2. Bästa resp. sämsta resultatet år 2018.
#  	3. Matematikkunskaper i norden år 2003 - 2018.
#  	4. Kontinuerligt förbättrat resp. försämrat år 2003 – 2018.
#  	5. Kvinnor presterar bättre än män under åren 2003–2018.
#  	6. Avsluta programmet.
#
#  Välj ett menyalternativ (1-6) :
# Felaktig inmatning, försök igen!
#
# 	1. Läs in CSV-filen.
#  	2. Bästa resp. sämsta resultatet år 2018.
#  	3. Matematikkunskaper i norden år 2003 - 2018.
#  	4. Kontinuerligt förbättrat resp. försämrat år 2003 – 2018.
#  	5. Kvinnor presterar bättre än män under åren 2003–2018.
#  	6. Avsluta programmet.
#
#  Välj ett menyalternativ (1-6) :
# Felaktig inmatning, försök igen!
#
# 	1. Läs in CSV-filen.
#  	2. Bästa resp. sämsta resultatet år 2018.
#  	3. Matematikkunskaper i norden år 2003 - 2018.
#  	4. Kontinuerligt förbättrat resp. försämrat år 2003 – 2018.
#  	5. Kvinnor presterar bättre än män under åren 2003–2018.
#  	6. Avsluta programmet.
#
# ...

# %%
# Skriv en inledande kommentar som talar om vad programmet gör.
#....
# Placera dina modulimpoter här:
import matplotlib.pyplot as plt
import csv

def read_file(filnamn):
    pisadata=[]
    with open (filnamn, "r") as file: #Öppnar filen och sedan läser
        read = csv.reader(file, delimiter = ";")
        for rad in read: #läser filen och använder for sats för att lägga in i en lista
            pisadata.append(rad)
    return pisadata

# Deluppgift 1: Funktioner från deluppgift 1 i ordning.
# Skriv din kod här:
def menytxt(): #Meny 
    print("1. Läs in csv-filen")
    print("2. Bästa resp. sämsta resultat år 2018")
    print("3. Matematikkunskaper i norden år 2003 – 2018.")
    print("4. Kontinuerligt förbättrat resp. försämrat år 2003 – 2018.")
    print("5. Kvinnor presterar bättre än män under åren 2003–2018")
    print("6. Avsluta programmet.")
    print("Välj ett menyalternativ (1-6):")

def meny(): # Använder whileloop för att skapa en meny. 
    while True:
        menytxt()
        val = int(input()) #frågar efter num och använder if satser "Meny" för att göra beslut
        if val == 1:
            filnamn =input("Ange filnamn eller tryck bara Enter för att använda data.csv: ") or 'pisadata.csv'
            pisadata= read_file(filnamn)   

            
        elif val ==2:
            pisdatasorted()
            
        elif val ==3:
            arsmedel(pisadata)
            medelvAr = (arsmedel(pisadata))
            nordtabell(pisadata,medelvAr)
            nordtabellgraf(pisadata,medelvAr)
  
            
        elif val ==4:
            battresamre(pisadata, True)  # För länder som har förbättrat sina resultat
            battresamre(pisadata, False) # För länder som har försämrat sina resultat

            
        elif val ==5:
            print(2)
                   
        elif val ==6:
            break


# Deluppgift 2: Funktioner från deluppgift 2 i ordning.
# Skriv din kod här:
    
def år2018(l,i,TF): # Använder mig av val så det inte behvös repeteras 
    pisadata.sort(reverse = TF, key= lambda i:i [1:]) # Sorterar datan från 2018+ använder sedan reverse för att fixa störst till minst
    for col in pisadata[1:11]: # For sats för att skriva ut data från 1 till 10 
        year18 = col[0:3]
        year18.sort(reverse=True)# sorterar störst till minst mellan female och male mellan 2018
        print(f"{year18[l]}--{year18[i]}") #skriver ut med val om vilken lista som ska ut
    
def pisdatasorted():
    print("De tio länder som hade bäst resultat år 2018")
    print("----------------")
    print("Land   Resultat")
    print("----------------")
    år2018(0,1,True)
    print("----------------")
    print("De tio länder som hade sämst resultat år 2018")
    print("----------------")
    print("Land   Resultat")
    print("----------------")
    år2018(0,2,False)
    print("----------------")


# Deluppgift 3: Funktioner från deluppgift 3 i ordning.
# Skriv din kod här:
def kolumnmedel(list, columnindex):
    totalsum = 0
    values = 0
    
    for row in list[2:]:
        try:
            value =int(row[columnindex]) 
            totalsum += value 
            values += 1 
        except ValueError:# om det går inte att ändra så hoppar den över.
            pass
    return round(totalsum/values) #beräknar medelvärdet


def arsmedel(list2):
    armedel= []
    for years in range(2003, 2019): # söker mellan 2003 till 2019
        for index,item in enumerate(list2[0]): 
            if str(years) in item or "medel" in item.lower(): 
                columnindex2 = index
                break
        else:
            continue # om inte så fortsätts sökningen 
        medelvärdet= kolumnmedel(list2, columnindex2) # använder oss av funktionen kolumnmedel för att beräkna medelvärdet 
        armedel.append(medelvärdet)
    return armedel

def nordtabell2(list3):

    land = ["Sweden","Norway","Denmark","Finland","Iceland"] 
    länder = [] 
    for w in land: # skapar for loops för att söka på de länder vi letar efter
        for rad in list3:
            if rad[0] == w: 
                länder.append(rad)
    return länder

def nordtabell(list4,medel):
    arsmedel2 = medel
    flipdata = nordtabell2(list4)
    data = [] 
    for i in flipdata:
        del i[:-6]
        data.append(i)
    flipdata2 = [list(row) for row in zip(*data)]

    
    år = [2018,2015,2012,2009,2006,2003] 
    

    print("\nKunskapsutveckling i matematik enligt PISA-undersökningen 2003 – 2018.") 
    print("                               Länder:")
    print("--------------------------------------------------------------------------------------")
    print("År  Sweden Norway Denmark Finland Iceland          Medelvärde alla länder")
    print("--------------------------------------------------------------------------------------")
    for år, flipdata2, arsmedel2 in zip(år, flipdata2, arsmedel2): 
        flipdata2_str = ' '.join(number + ' '*3 for number in flipdata2)
        print(f"{år}   {flipdata2_str}                   {arsmedel2}")
    

def nordtabellgraf(list5,medel):
    rsmedel2 = medel
    nordland = nordtabell2(list5)
    nyår = [2018,2015,2012,2009,2006,2003]
    arsmedel2 = medel
    flipdata2 = nordtabell2(list5)

    print(flipdata2) 
    plt.xlabel("År")
    plt.ylabel("Poäng")
    plt.title("PISA-undersökningen 2003 – 2018") 
    plt.grid(True)
    plt.legend()
    plt.show()

def kvinna_man(list2):
    listamf = []
    for row in pisadata:
        del row[-6:]
        listamf.append(row)
    for j in listamf: # skapar loops för att få värden till ints så det är enklare att jämnföra
        for i in range(1, len(j)):#använder mig av len för hur många loops 
            try:
                j[i] = int(j[i])
            except ValueError:# om det inte går att göra det till en int så fortsätter den
                pass
    newlist= []
    for jj in pisadata:
        for ii in range(1, len(jj), 2): #vi använder oss av for loops för att beräkna var 2 column
            kvinna= (jj[ii+1]) #flyttar fram för att få fram kvinna
            män= (jj[ii]) #män
            if kvinna > män:
                newlist.append(kvinna)#X

# Deluppgift 4: Funktioner från deluppgift 4 i ordning.
# Skriv din kod här:

def battresamre(pisadata, bättre):#Detta definierar en funktion som tar två parametrar pisadata som är en lista och bättre som en boolean variabel som letar efter förbättringar och försämringar
    if bättre:# kontrollerar  om värdet på bättre är sant eller falskt.
        print('Länder som hela tiden har förbättrat sina resultat mellan 2003-2018')
    else:
        print('Länder som hela tiden har försämrat sina resultat mellan 2003-2018')
    
    print('--------------------------------------------------------------------------------')
    print('{:<20} {:<10} {:<10} {:<10} {:<10} {:<10} {:<10}'.format("Land", "2018", "2015", "2012", "2009", "2006", "2003"))
    print('--------------------------------------------------------------------------------')

    for rad in pisadata[2:]: #en loop som går igenom varje rad i pisadata index 2 för att hoppa över de två första raderna som inte ger data
        land = rad[0] # tar landets namn från första indexet i varje rad
        resultat = rad[13:19]  # tar resultat från varje år mellan 2018 till 2003
        resultat = [int(r) if r else None for r in resultat] #gör de resultat från ovan till heltal
       
       #Denna två kontrollerar om det blir förbättring för varje land
        if bättre: 
            if all(resultat[i] >= resultat[i + 1] for i in range(len(resultat) - 1) if resultat[i] is not None and resultat[i + 1] is not None):
                print('{:<20} '.format(land) + ' '.join('{:<10}'.format(res) if res is not None else ' ' * 10 for res in resultat))

        #Denna kontrollerar om det blir försämring för varje land
        else: 
            
            if all(resultat[i] <= resultat[i + 1] for i in range(len(resultat) - 1) if resultat[i] is not None and resultat[i + 1] is not None):
                print('{:<20} '.format(land) + ' '.join('{:<10}'.format(res) if res is not None else ' ' * 10 for res in resultat))




# Deluppgift 5: Funktioner från deluppgift 5 i ordning.
# Skriv din kod här:
# Huvudprogram med Meny från deluppgift 0. Använd menyrubriker enl.uppgiftsbeskrivningen.
# Skriv din kod här:
meny()
# Out:
# 1. Läs in csv-filen
# 2. Bästa resp. sämsta resultat år 2018
# 3. Matematikkunskaper i norden år 2003 – 2018.
# 4. Kontinuerligt förbättrat resp. försämrat år 2003 – 2018.
# 5. Kvinnor presterar bättre än män under åren 2003–2018
# 6. Avsluta programmet.
# Välj ett menyalternativ (1-6):
# 1. Läs in csv-filen
# 2. Bästa resp. sämsta resultat år 2018
# 3. Matematikkunskaper i norden år 2003 – 2018.
# 4. Kontinuerligt förbättrat resp. försämrat år 2003 – 2018.
# 5. Kvinnor presterar bättre än män under åren 2003–2018
# 6. Avsluta programmet.
# Välj ett menyalternativ (1-6):
# No handles with labels found to put in legend.
# Kunskapsutveckling i matematik enligt PISA-undersökningen 2003 – 2018.
#                                Länder:
# --------------------------------------------------------------------------------------
# År  Sweden Norway Denmark Finland Iceland          Medelvärde alla länder
# --------------------------------------------------------------------------------------
# ...
